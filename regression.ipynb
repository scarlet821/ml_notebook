# %% [markdown]
# # Chapter 4: Training Models

# %% [markdown]
# ### The Normal Equation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = 2 * np.random.rand(100,1)
y = 4 + 3 * X + np.random.randn(100, 1)

print(len(X), len(y))
print(X.mean())
print(X.std())
# Out:
# 100 100
# 0.9303771301995877
# 0.6153766728759732

# %%
plt.scatter(X, y)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Generated Data")
plt.show()

# %%
X_b = np.c_[np.ones((100,1)), X]

theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T.dot(y))

theta_best
# Out:
# array([[4.00616588],
#        [3.03069913]])

# %%
b = theta_best[0]
m = theta_best[1]
y_pred = m * X + b
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression Fit")
plt.show()

# %%
mse = np.mean((y - y_pred) ** 2)
mse
# Out:
# np.float64(0.8169385916327765)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
lin_reg.predict([[0], [2]])
# Out:
# array([[ 4.00616588],
#        [10.06756413]])

# %%
theta_best_svd, residuals, rank, s = np.linalg.lstsq(X_b, y, rcond=1e-6)
theta_best_svd, residuals, rank, s
# Out:
# (array([[4.00616588],
#         [3.03069913]]),
#  array([81.69385916]),
#  np.int32(2),
#  array([14.35446216,  4.28700613]))
